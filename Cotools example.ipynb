# %%
# !pip install cord-19-tools

# %%
import cotools
from pprint import pprint
import os
import sys

# %% [markdown]
# First we have to download and extract the data. Currently the download function downloads the 4 sets of json data and puts them, extracted, into a directory:

# %%
downloaded = True # change me if you havent downloaded the data

if not downloaded:
    cotools.download(dir = 'data')
    
print(os.listdir('data'))
# Out:
# ['download.sh', 'noncomm_use_subset', 'biorxiv_medrxiv', 'pmc_custom_license', 'comm_use_subset']

# %% [markdown]
# Next, we can load the data! We will use the `Paperset` class. We initialize it by specifying the directory of JSON data:

# %%
comm_use = cotools.Paperset('data/comm_use_subset')
print(sys.getsizeof(comm_use))
# Out:
# 64

# %% [markdown]
# We access the data through indexing. Indices can either be ints or slices. Integer indices return dicts:

# %%
# laziness
print(sys.getsizeof(comm_use[0]))
# returns dict
print(type(comm_use[0]))
# dict
pprint(comm_use[0])
# Out:
# 376
# <class 'dict'>
# {'abstract': [{'cite_spans': [],
#                'ref_spans': [],
#                'section': 'Abstract',
#                'text': 'One single-nucleotide polymorphism from IL4 gene was '
#                        'significant for pooled respiratory infections '
#                        '(rs2070874; 1.66 [1.29-2.14]). We also detected an '
#                        'association of TLR2 gene with tuberculosis (rs5743708; '
#                        '3.19 [2.03-5.02]). Subset analyses identified CCL2 as '
#                        'an additional risk factor for tuberculosis (rs1024611; '
#                        'OR = 0.79 [0.72-0.88]). The IL4-TLR2-CCL2 axis could '
#                        'be a highly interesting target for translation towards '
#                        'clinical use. However, this conclusion is based on low '
#                        'credibility of evidence -almost 95% of all identified '
#                        'studies had strong risk of bias or confounding. Future '
#                        'studies must build upon larger-scale collaborations, '
#                        'but also strictly adhere to the highest evidence-based '
#                        'principles in study design, in order to reduce '
#                        'research waste and provide clinically translatable '
#                        'evidence.'}],
#  'back_matter': [{'cite_spans': [],
#                   'ref_spans': [],
#                   'section': 'Acknowledgements',
#                   'text': 'We would like to apologize to all authors whose '
#                           'studies we could not cite in this paper due to '
#                           'space limitations. We would also like to thank to '
#                           'all authors who provided additional information on '
#                           'their studies or provided raw data for purposes of '
#                           'this meta-analysis: '},
#                  {'cite_spans': [],
#                   'ref_spans': [],
#                   'section': 'Author Contributions',
#                   'text': 'O.P. and I.P. conceived the study idea; H.C., E.T., '
#                           'I.K., I.R., K.B. and M.J. further developed the '
#                           'idea and developed the current study scope; I.K., '
#                           'M.K., E.T. and O.P. developed and critically '
#                           'assessed the search strategy; I.P., A.G. and O.P. '
#                           'performed the search and extracted the data; I.P. '
#                           'and O.P. performed the data analysis; I.P., A.G. '
#                           'and O.P. drafted the manuscript; all authors '
#                           'approved the final manuscript version and are held '
#                           'accountable for all aspects of the work in ensuring '
#                           'that questions related to the accuracy or integrity '
#                           'of any part of the work are appropriately '
#                           'investigated and resolved. '}],
#  'bib_entries': {'BIBREF0': {'authors': [{'first': 'A',
#                                           'last': 'Fauci',
#                                           'middle': ['S'],
#                                           'suffix': ''},
#                                          {'first': 'D',
#                                           'last': 'Morens',
#                                           'middle': ['M'],
#                                           'suffix': ''}],
#                              'issn': '',
#                              'other_ids': {'DOI': ['10.1056/NEJMra1108296']},
#                              'pages': '454--461',
#                              'ref_id': 'b0',
#                              'title': 'The perpetual challenge of infectious '
#                                       'diseases',
#                              'venue': 'The New England journal of medicine',
#                              'volume': '366',
#                              'year': 2012},
#                  'BIBREF1': {'authors': [{'first': 'M',
#                                           'last': 'Fumagalli',
#                                           'middle': [],
#                                           'suffix': ''}],
#                              'issn': '',
#                              'other_ids': {'DOI': ['10.1371/journal.pgen.1000849']},
#                              'pages': '',
#                              'ref_id': 'b1',
#                              'title': 'Genome-wide identification of '
#                                       'susceptibility alleles for viral '
#                                       'infections through a population '
#                                       'genetics approach',
#                              'venue': 'PLoS genetics',
#                              'volume': '6',
#                              'year': 2010},
#                  'BIBREF10': {'authors': [{'first': 'S',
#                                            'last': 'Chapman',
#                                            'middle': ['J'],
#                                            'suffix': ''},
#                                           {'first': 'A',
#                                            'last': 'Hill',
#                                            'middle': ['V S'],
#                                            'suffix': ''}],
#                               'issn': '',
#                               'other_ids': {},
#                               'pages': '175--188',
#                               'ref_id': 'b10',
#                               'title': 'Human genetic susceptibility to '
#                                        'infectious disease',
#                               'venue': 'Nature Reviews Genetics',
#                               'volume': '13',
#                               'year': 2012},
#                  'BIBREF11': {'authors': [{'first': 'H',
#                                            'last': 'Colhoun',
#                                            'middle': ['M'],
#                                            'suffix': ''},
#                                           {'first': 'P',
#                                            'last': 'Mckeigue',
#                                            'middle': ['M'],
#                                            'suffix': ''},
#                                           {'first': 'G',
#                                            'last': 'Davey Smith',
#                                            'middle': [],
#                                            'suffix': ''}],
#                               'issn': '',
#                               'other_ids': {},
#                               'pages': '865--872',
#                               'ref_id': 'b11',
#                               'title': 'Problems of reporting genetic '
#                                        'associations with complex outcomes',
#                               'venue': 'Lancet',
#                               'volume': '361',
#                               'year': 2003},
#                  'BIBREF12': {'authors': [{'first': 'J',
#                                            'last': 'Affandi',
#                                            'middle': ['S'],
#                                            'suffix': ''},
#                                           {'first': 'P',
#                                            'last': 'Price',
#                                            'middle': [],
#                                            'suffix': ''},
#                                           {'first': 'G',
#                                            'last': 'Waterer',
#                                            'middle': [],
#                                            'suffix': ''}],
#                               'issn': '',
#                               'other_ids': {'DOI': ['10.1177/1753465810371484']},
#                               'pages': '161--176',
#                               'ref_id': 'b12',
#                               'title': 'Can immunogenetics illuminate the '
#                                        'diverse manifestations of respiratory '
#                                        'infections?',
#                               'venue': 'Therapeutic advances in respiratory '
#                                        'disease',
#                               'volume': '4',
#                               'year': 2010},
#                  'BIBREF13': {'authors': [{'first': 'C',
#                                            'last': 'Barry',
#                                            'middle': ['E'],
#                                            'suffix': ''}],
#                               'issn': '',
#                               'other_ids': {'DOI': ['10.1038/nrmicro2236']},
#                               'pages': '845--855',
#                               'ref_id': 'b13',
#                               'title': 'The spectrum of latent tuberculosis: '
#                                        'rethinking the biology and '
#                                        'intervention strategies',
#                               'venue': 'Nature reviews Microbiology',
#                               'volume': '7',
#                               'year': 2009},
#                  'BIBREF14': {'authors': [{'first': 'J',
#                                            'last': 'Ioannidis',
#                                            'middle': ['P'],
#                                            'suffix': ''}],
#                               'issn': '',
#                               'other_ids': {'DOI': ['10.1016/s0140-6736(13)62227-8']},
#                               'pages': '166--175',
#                               'ref_id': 'b14',
#                               'title': 'Increasing value and reducing waste in '
#                                        'research design, conduct, and analysis',
#                               'venue': 'Lancet',
#                               'volume': '383',
#                               'year': 2014},
#                  'BIBREF15': {'authors': [{'first': 'A',
#                                            'last': 'Hill',
#                                            'middle': ['V S'],
#                                            'suffix': ''}],
#                               'issn': '',
#                               'other_ids': {},
#                               'pages': '469--486',
#                               'ref_id': 'b15',
#                               'title': 'Aspects of genetic susceptibility to '
#                                        'human infectious diseases',
#                               'venue': 'Annual Review of Genetics',
#                               'volume': '40',
#                               'year': 2006},
#                  'BIBREF16': {'authors': [{'first': 'T',
#                                            'last': 'Thye',
#                                            'middle': [],
#                                            'suffix': ''}],
#                               'issn': '',
#                               'other_ids': {'DOI': ['10.1038/ng.1080']},
#                               'pages': '257--259',
#                               'ref_id': 'b16',
#                               'title': 'Common variants at 11p13 are '
#                                        'associated with susceptibility to '
#                                        'tuberculosis',
#                               'venue': 'Nature genetics',
#                               'volume': '44',
#                               'year': 2012},
#                  'BIBREF17': {'authors': [{'first': 'T',
#                                            'last': 'Thye',
#                                            'middle': [],
#                                            'suffix': ''}],
#                               'issn': '',
#                               'other_ids': {'DOI': ['10.1038/ng.639']},
#                               'pages': '739--741',
#                               'ref_id': 'b17',
#                               'title': 'Genome-wide association analyses '
#                                        'identifies a susceptibility locus for '
#                                        'tuberculosis on chromosome 18q11.2',
#                               'venue': 'Nature genetics',
#                               'volume': '42',
#                               'year': 2010},
#                  'BIBREF18': {'authors': [{'first': 'E',
#                                            'last': 'Allen',
#                                            'middle': ['K'],
#                                            'suffix': ''},
#                                           {'first': 'A',
#                                            'last': 'Manichaikul',
#                                            'middle': [],
#                                            'suffix': ''},
#                                           {'first': 'M',
#                                            'last': 'Sale',
#                                            'middle': ['M'],
#                                            'suffix': ''}],
#                               'issn': '',
#                               'other_ids': {'DOI': ['10.1007/s11882-013-0411-7']},
#                               'pages': '',
#                               'ref_id': 'b18',
#                               'title': 'Genetic contributors to otitis media: '
#                                        'agnostic discovery approaches. Current '
#                                        'allergy and asthma reports 14',
#                               'venue': '',
#                               'volume': '',
#                               'year': 2014},
#                  'BIBREF19': {'authors': [{'first': 'J',
#                                            'last': 'Casanova',
#                                            'middle': ['L'],
#                                            'suffix': ''},
#                                           {'first': 'L',
#                                            'last': 'Abel',
#                                            'middle': [],
#                                            'suffix': ''}],
#                               'issn': '',
#                               'other_ids': {},
#                               'pages': '215--243',
#                               'ref_id': 'b19',
#                               'title': 'The genetic theory of infectious '
#                                        'diseases: A brief history and selected '
#                                        'illustrations',
#                               'venue': 'Annual Review of Genomics and Human '
#                                        'Genetics',
#                               'volume': '14',
#                               'year': 2013},
#                  'BIBREF2': {'authors': [{'first': 'D',
#                                           'last': 'Morens',
#                                           'middle': ['M'],
#                                           'suffix': ''},
#                                          {'first': 'G',
#                                           'last': 'Folkers',
#                                           'middle': ['K'],
#                                           'suffix': ''},
#                                          {'first': 'A',
#                                           'last': 'Fauci',
#                                           'middle': ['S'],
#                                           'suffix': ''}],
#                              'issn': '',
#                              'other_ids': {'DOI': ['10.1016/s1473-3099(08)70256-1']},
#                              'pages': '710--719',
#                              'ref_id': 'b2',
#                              'title': 'Emerging infections: a perpetual '
#                                       'challenge',
#                              'venue': 'The Lancet Infectious diseases',
#                              'volume': '8',
#                              'year': 2008},
#                  'BIBREF20': {'authors': [{'first': 'L',
#                                            'last': 'Quintana-Murci',
#                                            'middle': [],
#                                            'suffix': ''},
#                                           {'first': 'A',
#                                            'last': 'Alcais',
#                                            'middle': [],
#                                            'suffix': ''},
#                                           {'first': 'L',
#                                            'last': 'Abel',
#                                            'middle': [],
#                                            'suffix': ''},
#                                           {'first': 'J',
#                                            'last': 'Casanova',
#                                            'middle': ['L'],
#                                            'suffix': ''}],
#                               'issn': '',
#                               'other_ids': {'DOI': ['10.1038/ni1535']},
#                               'pages': '1165--1171',
#                               'ref_id': 'b20',
#                               'title': 'Immunology in natura: clinical, '
#                                        'epidemiological and evolutionary '
#                                        'genetics of infectious diseases',
#                               'venue': 'Nature immunology',
#                               'volume': '8',
#                               'year': 2007},
#                  'BIBREF21': {'authors': [{'first': 'J',
#                                            'last': 'Manry',
#                                            'middle': [],
#                                            'suffix': ''},
#                                           {'first': 'L',
#                                            'last': 'Quintana-Murci',
#                                            'middle': [],
#                                            'suffix': ''}],
#                               'issn': '',
#                               'other_ids': {'DOI': ['10.1101/cshperspect.a012450']},
#                               'pages': '',
#                               'ref_id': 'b21',
#                               'title': 'A genome-wide perspective of human '
#                                        'diversity and its implications in '
#                                        'infectious disease',
#                               'venue': 'Cold Spring Harbor Perspectives in '
#                                        'Biology',
#                               'volume': '3',
#                               'year': 2013},
#                  'BIBREF22': {'authors': [{'first': 'K',
#                                            'last': 'Patterson',
#                                            'middle': ['D'],
#                                            'suffix': ''},
#                                           {'first': 'G',
#                                            'last': 'Pyle',
#                                            'middle': ['F'],
#                                            'suffix': ''}],
#                               'issn': '',
#                               'other_ids': {},
#                               'pages': '4--21',
#                               'ref_id': 'b22',
#                               'title': 'The geography and mortality of the '
#                                        '1918 influenza pandemic',
#                               'venue': 'Bulletin of the history of medicine',
#                               'volume': '65',
#                               'year': 1991},
#                  'BIBREF23': {'authors': [{'first': 'N',
#                                            'last': 'Johnson',
#                                            'middle': ['P'],
#                                            'suffix': ''},
#                                           {'first': 'J',
#                                            'last': 'Mueller',
#                                            'middle': [],
#                                            'suffix': ''}],
#                               'issn': '',
#                               'other_ids': {},
#                               'pages': '105--115',
#                               'ref_id': 'b23',
#                               'title': 'Updating the accounts: global '
#                                        'mortality of the 1918-1920 "Spanish" '
#                                        'influenza pandemic',
#                               'venue': 'Bulletin of the history of medicine',
#                               'volume': '76',
#                               'year': 2002},
#                  'BIBREF24': {'authors': [{'first': 'Le',
#                                            'last': 'Chevalier',
#                                            'middle': [],
#                                            'suffix': ''},
#                                           {'first': 'F',
#                                            'last': 'Cascioferro',
#                                            'middle': [],
#                                            'suffix': ''},
#                                           {'first': 'A',
#                                            'last': 'Majlessi',
#                                            'middle': [],
#                                            'suffix': ''},
#                                           {'first': 'L',
#                                            'last': 'Herrmann',
#                                            'middle': [],
#                                            'suffix': ''},
#                                           {'first': 'J',
#                                            'last': 'Brosch',
#                                            'middle': ['L'],
#                                            'suffix': ''},
#                                           {'first': 'R',
#                                            'last': '',
#                                            'middle': [],
#                                            'suffix': ''}],
#                               'issn': '',
#                               'other_ids': {'DOI': ['10.2217/fmb.14.70']},
#                               'pages': '969--985',
#                               'ref_id': 'b24',
#                               'title': 'Mycobacterium tuberculosis '
#                                        'evolutionary pathogenesis and its '
#                                        'putative impact on drug development',
#                               'venue': 'Future microbiology',
#                               'volume': '9',
#                               'year': 2014},
#                  'BIBREF25': {'authors': [{'first': 'S',
#                                            'last': 'Gagneux',
#                                            'middle': [],
#                                            'suffix': ''}],
#                               'issn': '',
#                               'other_ids': {'DOI': ['10.1098/rstb.2011.0316']},
#                               'pages': '850--859',
#                               'ref_id': 'b25',
#                               'title': 'Host-pathogen coevolution in human '
#                                        'tuberculosis',
#                               'venue': 'Philosophical transactions of the '
#                                        'Royal Society of London. Series B, '
#                                        'Biological sciences',
#                               'volume': '367',
#                               'year': 2012},
#                  'BIBREF26': {'authors': [{'first': 'R',
#                                            'last': 'Hershberg',
#                                            'middle': [],
#                                            'suffix': ''}],
#                               'issn': '',
#                               'other_ids': {'DOI': ['10.1371/journal.pbio.0060311']},
#                               'pages': '',
#                               'ref_id': 'b26',
#                               'title': 'High functional diversity in '
#                                        'Mycobacterium tuberculosis driven by '
#                                        'genetic drift and human demography',
#                               'venue': 'PLoS biology',
#                               'volume': '6',
#                               'year': 2008},
#                  'BIBREF27': {'authors': [],
#                               'issn': '',
#                               'other_ids': {},
#                               'pages': '',
#                               'ref_id': 'b27',
#                               'title': 'Global tuberculosis report',
#                               'venue': '',
#                               'volume': '',
#                               'year': 2014},
#                  'BIBREF28': {'authors': [{'first': 'C',
#                                            'last': 'Walker',
#                                            'middle': ['L'],
#                                            'suffix': ''}],
#                               'issn': '13',
#                               'other_ids': {'DOI': ['10.1016/s0140-6736']},
#                               'pages': '60222--60228',
#                               'ref_id': 'b28',
#                               'title': 'Global burden of childhood pneumonia '
#                                        'and diarrhoea',
#                               'venue': 'Lancet',
#                               'volume': '381',
#                               'year': 2013},
#                  'BIBREF29': {'authors': [{'first': 'H',
#                                            'last': 'Nair',
#                                            'middle': [],
#                                            'suffix': ''}],
#                               'issn': '10',
#                               'other_ids': {'DOI': ['10.1016/s0140-6736']},
#                               'pages': '60206--60207',
#                               'ref_id': 'b29',
#                               'title': 'Global burden of acute lower '
#                                        'respiratory infections due to '
#                                        'respiratory syncytial virus in young '
#                                        'children: a systematic review and '
#                                        'meta-analysis',
#                               'venue': 'Lancet',
#                               'volume': '375',
#                               'year': 2010},
#                  'BIBREF3': {'authors': [{'first': 'T',
#                                           'last': 'Sorensen',
#                                           'middle': ['I'],
#                                           'suffix': ''},
#                                          {'first': 'G',
#                                           'last': 'Nielsen',
#                                           'middle': ['G'],
#                                           'suffix': ''},
#                                          {'first': 'P',
#                                           'last': 'Andersen',
#                                           'middle': ['K'],
#                                           'suffix': ''},
#                                          {'first': 'T',
#                                           'last': 'Teasdale',
#                                           'middle': ['W'],
#                                           'suffix': ''}],
#                              'issn': '',
#                              'other_ids': {'DOI': ['10.1056/nejm198803243181202']},
#                              'pages': '727--732',
#                              'ref_id': 'b3',
#                              'title': 'Genetic and environmental influences on '
#                                       'premature death in adult adoptees',
#                              'venue': 'The New England journal of medicine',
#                              'volume': '318',
#                              'year': 1988},
#                  'BIBREF30': {'authors': [{'first': 'R',
#                                            'last': 'Fouchier',
#                                            'middle': ['A'],
#                                            'suffix': ''}],
#                               'issn': '',
#                               'other_ids': {'DOI': ['10.1038/423240a']},
#                               'pages': '',
#                               'ref_id': 'b30',
#                               'title': "Aetiology: Koch's postulates fulfilled "
#                                        'for SARS virus',
#                               'venue': 'Nature',
#                               'volume': '423',
#                               'year': 2003},
#                  'BIBREF31': {'authors': [{'first': 'L',
#                                            'last': 'Poon',
#                                            'middle': ['L'],
#                                            'suffix': ''},
#                                           {'first': 'Y',
#                                            'last': 'Guan',
#                                            'middle': [],
#                                            'suffix': ''},
#                                           {'first': 'J',
#                                            'last': 'Nicholls',
#                                            'middle': ['M'],
#                                            'suffix': ''},
#                                           {'first': 'K',
#                                            'last': 'Yuen',
#                                            'middle': ['Y'],
#                                            'suffix': ''},
#                                           {'first': 'J',
#                                            'last': 'Peiris',
#                                            'middle': ['S'],
#                                            'suffix': ''}],
#                               'issn': '',
#                               'other_ids': {'DOI': ['10.1016/s1473-3099(04)01172-7']},
#                               'pages': '663--671',
#                               'ref_id': 'b31',
#                               'title': 'The aetiology, origins, and diagnosis '
#                                        'of severe acute respiratory syndrome',
#                               'venue': 'The Lancet. Infectious diseases',
#                               'volume': '4',
#                               'year': 2004},
#                  'BIBREF32': {'authors': [{'first': 'A',
#                                            'last': 'Alcaïs',
#                                            'middle': [],
#                                            'suffix': ''}],
#                               'issn': '',
#                               'other_ids': {},
#                               'pages': '18--33',
#                               'ref_id': 'b32',
#                               'title': 'Life-threatening infectious diseases '
#                                        'of childhood: Single-gene inborn '
#                                        'errors of immunity?',
#                               'venue': 'Ann NY Acad Sci',
#                               'volume': '1214',
#                               'year': 2010},
#                  'BIBREF33': {'authors': [{'first': 'A',
#                                            'last': 'Alcaïs',
#                                            'middle': [],
#                                            'suffix': ''},
#                                           {'first': 'L',
#                                            'last': 'Abel',
#                                            'middle': [],
#                                            'suffix': ''},
#                                           {'first': 'J',
#                                            'last': 'Casanova',
#                                            'middle': ['L'],
#                                            'suffix': ''}],
#                               'issn': '',
#                               'other_ids': {},
#                               'pages': '2506--2514',
#                               'ref_id': 'b33',
#                               'title': 'Human genetics of infectious diseases: '
#                                        'Between proof of principle and '
#                                        'paradigm',
#                               'venue': 'Journal of Clinical Investigation',
#                               'volume': '119',
#                               'year': 2009},
#                  'BIBREF34': {'authors': [{'first': 'P',
#                                            'last': 'Choi',
#                                            'middle': [],
#                                            'suffix': ''},
#                                           {'first': 'H',
#                                            'last': 'Reiser',
#                                            'middle': [],
#                                            'suffix': ''}],
#                               'issn': '',
#                               'other_ids': {},
#                               'pages': '317--319',
#                               'ref_id': 'b34',
#                               'title': 'IL-4: role in disease and regulation '
#                                        'of production',
#                               'venue': 'Clinical and experimental immunology',
#                               'volume': '113',
#                               'year': 1998},
#                  'BIBREF35': {'authors': [{'first': 'G',
#                                            'last': 'Hershey',
#                                            'middle': ['K'],
#                                            'suffix': ''},
#                                           {'first': 'M',
#                                            'last': 'Friedrich',
#                                            'middle': ['F'],
#                                            'suffix': ''},
#                                           {'first': 'L',
#                                            'last': 'Esswein',
#                                            'middle': ['A'],
#                                            'suffix': ''},
#                                           {'first': 'M',
#                                            'last': 'Thomas',
#                                            'middle': ['L'],
#                                            'suffix': ''},
#                                           {'first': 'T',
#                                            'last': 'Chatila',
#                                            'middle': ['A'],
#                                            'suffix': ''}],
#                               'issn': '',
#                               'other_ids': {},
#                               'pages': '1720--1725',
#                               'ref_id': 'b35',
#                               'title': 'The association of atopy with a '
#                                        'gain-of-function mutation in the alpha '
#                                        'subunit of the interleukin-4 receptor',
#                               'venue': 'The New England journal of medicine',
#                               'volume': '337',
#                               'year': 1997},
#                  'BIBREF36': {'authors': [{'first': 'C',
#                                            'last': 'Newton',
#                                            'middle': [],
#                                            'suffix': ''}],
#                               'issn': '',
#                               'other_ids': {},
#                               'pages': '5234--5240',
#                               'ref_id': 'b36',
#                               'title': 'Induction of interleukin-4 (IL-4) by '
#                                        'Legionella pneumophila infection in '
#                                        'BALB/c mice and regulation of tumor '
#                                        'necrosis factor alpha, IL-6, and '
#                                        'IL-1beta',
#                               'venue': 'Infection and immunity',
#                               'volume': '68',
#                               'year': 2000},
#                  'BIBREF37': {'authors': [{'first': 'J',
#                                            'last': 'Van Bergenhenegouwen',
#                                            'middle': [],
#                                            'suffix': ''}],
#                               'issn': '',
#                               'other_ids': {'DOI': ['10.1189/jlb.0113003']},
#                               'pages': '885--902',
#                               'ref_id': 'b37',
#                               'title': 'TLR2 & Co: a critical analysis of the '
#                                        'complex interactions between TLR2 and '
#                                        'coreceptors',
#                               'venue': 'Journal of leukocyte biology',
#                               'volume': '94',
#                               'year': 2013},
#                  'BIBREF38': {'authors': [{'first': 'A',
#                                            'last': 'Ogus',
#                                            'middle': ['C'],
#                                            'suffix': ''}],
#                               'issn': '',
#                               'other_ids': {},
#                               'pages': '219--223',
#                               'ref_id': 'b38',
#                               'title': 'The Arg753GLn polymorphism of the '
#                                        'human toll-like receptor 2 gene in '
#                                        'tuberculosis disease',
#                               'venue': 'The European respiratory journal',
#                               'volume': '23',
#                               'year': 2004},
#                  'BIBREF39': {'authors': [{'first': 'I',
#                                            'last': 'Saraav',
#                                            'middle': [],
#                                            'suffix': ''},
#                                           {'first': 'S',
#                                            'last': 'Singh',
#                                            'middle': [],
#                                            'suffix': ''},
#                                           {'first': 'S',
#                                            'last': 'Sharma',
#                                            'middle': [],
#                                            'suffix': ''}],
#                               'issn': '',
#                               'other_ids': {'DOI': ['10.1038/icb.2014.52']},
#                               'pages': '741--746',
#                               'ref_id': 'b39',
#                               'title': 'Outcome of Mycobacterium tuberculosis '
#                                        'and Toll-like receptor interaction: '
#                                        'immune response or immune evasion?',
#                               'venue': 'Immunology and cell biology',
#                               'volume': '92',
#                               'year': 2014},
#                  'BIBREF40': {'authors': [{'first': 'D',
#                                            'last': 'Underhill',
#                                            'middle': ['M'],
#                                            'suffix': ''},
#                                           {'first': 'A',
#                                            'last': 'Ozinsky',
#                                            'middle': [],
#                                            'suffix': ''},
#                                           {'first': 'K',
#                                            'last': 'Smith',
#                                            'middle': ['D'],
#                                            'suffix': ''},
#                                           {'first': 'A',
#                                            'last': 'Aderem',
#                                            'middle': [],
#                                            'suffix': ''}],
#                               'issn': '',
#                               'other_ids': {},
#                               'pages': '14459--14463',
#                               'ref_id': 'b40',
#                               'title': 'Toll-like receptor-2 mediates '
#                                        'mycobacteria-induced proinflammatory '
#                                        'signaling in macrophages',
#                               'venue': 'Proceedings of the National Academy of '
#                                        'Sciences of the United States of '
#                                        'America',
#                               'volume': '96',
#                               'year': 1999},
#                  'BIBREF41': {'authors': [{'first': 'L',
#                                            'last': 'Oliveira-Nascimento',
#                                            'middle': [],
#                                            'suffix': ''},
#                                           {'first': 'P',
#                                            'last': 'Massari',
#                                            'middle': [],
#                                            'suffix': ''},
#                                           {'first': 'L',
#                                            'last': 'Wetzler',
#                                            'middle': [],
#                                            'suffix': ''}],
#                               'issn': '',
#                               'other_ids': {},
#                               'pages': '',
#                               'ref_id': 'b41',
#                               'title': 'The role of TLR2 in infection and '
#                                        'immunity',
#                               'venue': 'Front Immunol',
#                               'volume': '3',
#                               'year': 2012},
#                  'BIBREF42': {'authors': [{'first': 'A',
#                                            'last': 'Mcbride',
#                                            'middle': [],
#                                            'suffix': ''},
#                                           {'first': 'K',
#                                            'last': 'Bhatt',
#                                            'middle': [],
#                                            'suffix': ''},
#                                           {'first': 'P',
#                                            'last': 'Salgame',
#                                            'middle': [],
#                                            'suffix': ''}],
#                               'issn': '',
#                               'other_ids': {'DOI': ['10.1128/iai.01076-10']},
#                               'pages': '1118--1123',
#                               'ref_id': 'b42',
#                               'title': 'Development of a secondary immune '
#                                        'response to Mycobacterium tuberculosis '
#                                        'is independent of Toll-like receptor 2',
#                               'venue': 'Infection and immunity',
#                               'volume': '79',
#                               'year': 2011},
#                  'BIBREF43': {'authors': [{'first': 'M',
#                                            'last': 'Xia',
#                                            'middle': [],
#                                            'suffix': ''},
#                                           {'first': 'Z',
#                                            'last': 'Sui',
#                                            'middle': [],
#                                            'suffix': ''}],
#                               'issn': '',
#                               'other_ids': {'DOI': ['10.1517/13543770902755129']},
#                               'pages': '295--303',
#                               'ref_id': 'b43',
#                               'title': 'Recent developments in CCR2 '
#                                        'antagonists',
#                               'venue': 'Expert opinion on therapeutic patents',
#                               'volume': '19',
#                               'year': 2009},
#                  'BIBREF44': {'authors': [{'first': 'C',
#                                            'last': 'Paiva',
#                                            'middle': ['N'],
#                                            'suffix': ''}],
#                               'issn': '',
#                               'other_ids': {'DOI': ['10.1189/jlb.0309187']},
#                               'pages': '1239--1246',
#                               'ref_id': 'b44',
#                               'title': 'CCL2/MCP-1 controls parasite burden, '
#                                        'cell infiltration, and mononuclear '
#                                        'activation during acute Trypanosoma '
#                                        'cruzi infection',
#                               'venue': 'Journal of leukocyte biology',
#                               'volume': '86',
#                               'year': 2009},
#                  'BIBREF46': {'authors': [{'first': 'R',
#                                            'last': 'Hussain',
#                                            'middle': [],
#                                            'suffix': ''},
#                                           {'first': 'A',
#                                            'last': 'Ansari',
#                                            'middle': [],
#                                            'suffix': ''},
#                                           {'first': 'N',
#                                            'last': 'Talat',
#                                            'middle': [],
#                                            'suffix': ''},
#                                           {'first': 'Z',
#                                            'last': 'Hasan',
#                                            'middle': [],
#                                            'suffix': ''},
#                                           {'first': 'G',
#                                            'last': 'Dawood',
#                                            'middle': [],
#                                            'suffix': ''}],
#                               'issn': '',
#                               'other_ids': {'DOI': ['10.1371/journal.pone.0025803']},
#                               'pages': '',
#                               'ref_id': 'b46',
#                               'title': 'CCL2/MCP-I genotype-phenotype '
#                                        'relationship in latent tuberculosis '
#                                        'infection',
#                               'venue': 'PLoS One',
#                               'volume': '6',
#                               'year': 2011},
#                  'BIBREF47': {'authors': [{'first': 'S',
#                                            'last': 'Deshmane',
#                                            'middle': ['L'],
#                                            'suffix': ''},
#                                           {'first': 'S',
#                                            'last': 'Kremlev',
#                                            'middle': [],
#                                            'suffix': ''},
#                                           {'first': 'S',
#                                            'last': 'Amini',
#                                            'middle': [],
#                                            'suffix': ''},
#                                           {'first': 'B',
#                                            'last': 'Sawaya',
#                                            'middle': ['E'],
#                                            'suffix': ''}],
#                               'issn': '',
#                               'other_ids': {'DOI': ['10.1089/jir.2008.0027']},
#                               'pages': '313--326',
#                               'ref_id': 'b47',
#                               'title': 'Monocyte chemoattractant protein-1 '
# ...
#                         'estimates ranging from the best AAA to worst CCC '
#                         'score, which was applied to every data point in RISE '
#                         'database (and not for the meta-analysis results, as '
#                         'the Venice criteria is intended to). Since '
#                         'information bias can affect several aspects of the '
#                         'study, we also divided information bias risk domain '
#                         'in three separate sub-scores, relating to cases and '
#                         'controls selection and genotyping procedures, with '
#                         'the worst of all three defining the overall '
#                         'information bias risk. All CSI scoring was done '
#                         'independently by two authors, and all discrepancies '
#                         'were settled by an agreement or input from a third '
#                         'author (there were 313 or 14.2% data points with '
#                         'initially dissimilar grades, providing good agreement '
#                         'with kappa coefficient of 0.717 and standard error '
#                         'for kappa of 0.011).'},
#                {'cite_spans': [{'end': 1483,
#                                 'ref_id': 'BIBREF87',
#                                 'start': 1479,
#                                 'text': '[85]'},
#                                {'end': 1488,
#                                 'ref_id': 'BIBREF88',
#                                 'start': 1484,
#                                 'text': '[86]'},
#                                {'end': 1493,
#                                 'ref_id': 'BIBREF89',
#                                 'start': 1489,
#                                 'text': '[87]'}],
#                 'ref_spans': [],
#                 'section': 'Risk of bias in individual studies.',
#                 'text': 'As an additional quality control check, we '
#                         're-calculated Hardy-Weinberg test for every control '
#                         'set included in the analysis, using a two tailed '
#                         'chi-square test or an exact test, when appropriate. '
#                         'Those data points that failed HWE test at the level '
#                         'of P < 0.05 were downgraded to C in the CSI score '
#                         '(there were 225 out of 2,209, or 10.2% of all '
#                         'analysed data points that failed HWE), in order to '
#                         'reflect possible methodological limitations of failed '
#                         'HWE (which indicates both the risk for selection '
#                         'and/or information bias). Where cases from a single '
#                         'study were classified as moderate or severe, we did '
#                         'not determine Selection domain of CSI score (a total '
#                         'of 246 data points). In such instances we assigned 0 '
#                         'to selection bias risk, as there was no selection '
#                         'process involved, and second-stage analysis was '
#                         'performed Summary measures and synthesis of results. '
#                         'In the first step of meta-analysis we calculated all '
#                         'odds ratios anew from raw data, in order to provide a '
#                         'common analytic framework and reduce possible '
#                         'differences in data analysis. In order to better '
#                         'understand the genetic architecture underlying '
#                         'gene-disease association, we performed analyses using '
#                         'four separate genetic models: allelic, dominant, '
#                         'recessive and heterozygote advantage. Model selection '
#                         'was based on commonly used allelic model, two '
#                         'additional models that assume different inheritance '
#                         'effects (dominant and recessive), followed by the '
#                         'heterozygote advantage, as previous studies reported '
#                         'such results [85] [86] [87] . All calculations were '
#                         'therefore based on allele counts, rather than exact '
#                         'cases and controls counts. We compared the results of '
#                         'different models, in an attempt to provide broader '
#                         'insight into genetic architecture.'},
#                {'cite_spans': [],
#                 'ref_spans': [],
#                 'section': 'Risk of bias in individual studies.',
#                 'text': 'Minor allele frequencies in Homo sapiens Short '
#                         'Variation (GRCh38) data set were obtained from '
#                         'Ensembl Biomart on 08.12.2014 88 . We then performed '
#                         'a series of meta-analyses for all SNPs where four or '
#                         'more data points were available for a single SNP. We '
#                         'used random effects meta-analysis, assuming '
#                         'differences in designs and ethnic composition of '
#                         'individual studies. We also calculated fixed-effects '
#                         'model, in order to compare the results. We used I 2 '
#                         'statistics and corresponding confidence intervals as '
#                         'a measure of heterogeneity.'},
#                {'cite_spans': [],
#                 'ref_spans': [],
#                 'section': 'Risk of bias in individual studies.',
#                 'text': 'In order to account for multiple testing as a result '
#                         'of numerous meta-analyses and different genetic '
#                         'models being performed, we used Bayesian '
#                         'false-discovery probability (BFDP) 72 . It was '
#                         'calculated for nominally significant results only, '
#                         'with a threshold of 0.2, using an online free version '
#                         'of the BFDP calculator '
#                         '(http://faculty.washington.edu/jonno/BFDP.xls). In '
#                         'addition, we calculated BFDP using two prior '
#                         'probabilities, with medium/low prior level (0.05 to '
#                         'E-03), consistent with a candidate gene; and very low '
#                         'prior level (E-04 to E-06), consistent with a random '
#                         'SNP. The advantage of this approach over the commonly '
#                         'used corrections is that it is not dependent on the '
#                         'number of tests performed, as it relies on odds '
#                         'ratios and confidence intervals for calculation. In '
#                         'addition, it provides conceptual improvement over the '
#                         'similar methods, such as false-positive report '
#                         'probability (FPRP) 89 . Due to substantial '
#                         'requirements for appropriate use of publication bias '
#                         'analysis methods 90 , we only examined publication '
#                         'bias visually.'},
#                {'cite_spans': [],
#                 'ref_spans': [],
#                 'section': 'Risk of bias in individual studies.',
#                 'text': 'All analyses were performed in R, version 2.15.3 91 . '
#                         'Meta-analysis was performed with package meta 3.2-0 '
#                         'and metabin, forest and funnel functions 92 . '
#                         'Hardy-Weinberg equilibrium testing was performed in '
#                         'HardyWeinberg_1.5.2 package 93 , with HWExactMat or '
#                         'HWChisqMat functions, based on the cell expected '
#                         'frequencies.'},
#                {'cite_spans': [],
#                 'ref_spans': [],
#                 'section': 'Risk of bias in individual studies.',
#                 'text': 'Risk of bias across studies. For purpose of '
#                         'meta-analysis credibility assessment, we used Venice '
#                         'criteria 81 , in all instances of nominally '
#                         'significant results. Study power was assessed on the '
#                         'basis of sample sizes (with sample sizes of up to a '
#                         '1,000 graded as C, 1,001-10,000 graded as B, and over '
#                         '10,001 graded as A). Heterogeneity was based on I 2 '
#                         'statistics (graded as A in case of 0-25%, B in case '
#                         'of 26-50% and C in case of I2 being over 50% ), while '
#                         'the third score domain was fixed as C (weak '
#                         'credibility), due to very prevalent risk of bias in '
#                         'primary studies.'}],
#  'metadata': {'authors': [{'affiliation': {},
#                            'email': '',
#                            'first': 'Inga',
#                            'last': 'Patarčić',
#                            'middle': [],
#                            'suffix': ''},
#                           {'affiliation': {},
#                            'email': '',
#                            'first': 'Andrea',
#                            'last': 'Gelemanović',
#                            'middle': [],
#                            'suffix': ''},
#                           {'affiliation': {},
#                            'email': '',
#                            'first': 'Mirna',
#                            'last': 'Kirin',
#                            'middle': [],
#                            'suffix': ''},
#                           {'affiliation': {},
#                            'email': '',
#                            'first': 'Ivana',
#                            'last': 'Kolčić',
#                            'middle': [],
#                            'suffix': ''},
#                           {'affiliation': {'institution': 'University of '
#                                                           'Edinburgh',
#                                            'laboratory': '',
#                                            'location': {'country': 'UK',
#                                                         'settlement': 'Edinburgh'}},
#                            'email': '',
#                            'first': 'Evropi',
#                            'last': 'Theodoratou',
#                            'middle': [],
#                            'suffix': ''},
#                           {'affiliation': {'institution': 'University of '
#                                                           'Edinburgh',
#                                            'laboratory': '',
#                                            'location': {'country': 'UK',
#                                                         'settlement': 'Midlothian'}},
#                            'email': '',
#                            'first': 'Kenneth',
#                            'last': 'Baillie',
#                            'middle': ['J'],
#                            'suffix': ''},
#                           {'affiliation': {'institution': 'University of '
#                                                           'Amsterdam',
#                                            'laboratory': '',
#                                            'location': {'country': 'The '
#                                                                    'Netherlands',
#                                                         'settlement': 'Amsterdam'}},
#                            'email': '',
#                            'first': 'Menno',
#                            'last': 'De Jong',
#                            'middle': ['D'],
#                            'suffix': ''},
#                           {'affiliation': {'institution': 'University of '
#                                                           'Edinburgh',
#                                            'laboratory': '',
#                                            'location': {'country': 'UK',
#                                                         'settlement': 'Edinburgh'}},
#                            'email': '',
#                            'first': 'Igor',
#                            'last': 'Rudan',
#                            'middle': [],
#                            'suffix': ''},
#                           {'affiliation': {'institution': 'University of '
#                                                           'Edinburgh',
#                                            'laboratory': '',
#                                            'location': {'country': 'UK',
#                                                         'settlement': 'Edinburgh'}},
#                            'email': '',
#                            'first': 'Harry',
#                            'last': 'Campbell',
#                            'middle': [],
#                            'suffix': ''},
#                           {'affiliation': {'institution': 'University of '
#                                                           'Edinburgh',
#                                            'laboratory': '',
#                                            'location': {'country': 'UK',
#                                                         'settlement': 'Edinburgh'}},
#                            'email': '',
#                            'first': 'Ozren',
#                            'last': 'Polašek',
#                            'middle': [],
#                            'suffix': ''}],
#               'title': 'The role of host genetic factors in respiratory tract '
#                        'infectious diseases: systematic review, meta- analyses '
#                        'and field synopsis'},
#  'paper_id': '4a7c2c60763755a14783f728e9b4cde8bf899f09',
#  'ref_entries': {'FIGREF0': {'latex': None,
#                              'text': 'Quality score assessment, based on '
#                                      'confounding, selection bias and '
#                                      'information bias risk, based on 1,963 '
#                                      'data points from RISE database (only '
#                                      'data points with all three CSI domain '
#                                      'scores were analysed here).',
#                              'type': 'figure'},
#                  'TABREF0': {'latex': None,
#                              'text': '. The first one was IL4 gene, for pooled '
#                                      'result in allelic model (rs2070874; OR = '
#                                      '0.79, 95% CI [0.70-0.89]; Supplementary '
#                                      'Figure 2), and pooled result in '
#                                      'recessive model (rs2070874; 1.66 '
#                                      '[1.29-2.14]; Supplementary Figure 3). '
#                                      'The second one was TLR2 gene for '
#                                      'tuberculosis in allelic model '
#                                      '(rs5743708; 3.19 [2.03-5.02]; '
#                                      'Supplementary Figure 4). We did not '
#                                      'detect strong traces of publication bias '
#                                      'in all meta-analyses (plots available in '
#                                      'RISEdb website). Subset analysis of '
#                                      'methodologically better studies (with '
#                                      'controls of known exposure to the '
#                                      'pathogen) revealed five nominally '
#                                      'significant results, with a single '
#                                      'noteworthy result (Supplementary Table '
#                                      '7) -CCL2 gene (rs1024611; OR = 0.79 '
#                                      '[0.72-0.88];',
#                              'type': 'table'}}}

# %% [markdown]
# Slice indices return lists of dicts:

# %%
print(sys.getsizeof(comm_use[15:65]))
print(type(comm_use[15:65]))
print([type(x) for x in comm_use[15:65]])
# Out:
# 536
# <class 'list'>
# [<class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>]

# %% [markdown]
# Please make PRs to make this more useful! To be added:
#
# * Metadata
# * Other datasets??
